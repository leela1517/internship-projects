# %% [markdown]
# Q-Name any 3 ide of python -->
# A- idle, pycharm, vscode, jupyter, spyder,vscode,

# %% [raw]
# Q- Guess the output

# %%
print(r'data science technology \n rocks')
# Out:
# data science technology \n rocks

# %% [markdown]
# Q - what is output

# %%
name = 'data science'
print(name[-7])
# Out:
# s

# %% [markdown]
# Q- How to delate values (95,14,12) ?
# nums = [25,36,95,14,12,26]

# %%
nums = [25,36,95,14,12,26]
del nums[2:5]
nums
# Out:
# [25, 36, 26]

# %% [markdown]
# Q- differecen between set & list
# Q- Name any 4 datatype with defination

# %% [markdown]
# question-
# print(7 << 2)
# print(125|265)
# print(652^125)
# print(288<<2)>>(26//6)

# %% [markdown]
# Q- list any 5 math function and their working

# %% [markdown]
# Q- write a code to find cube of the number
# Q- take the input from the user using input() and also using command line

# %%
a = 3
a ** 3
# Out:
# 27

# %% [markdown]
# Q- write a code to check weather number is positive or negative

# %%
x = -5
if x>=0:
    print('Number is positive')
else:
    print('Number is negative')
# Out:
# Number is negative

# %% [markdown]
# Q- Python program to find the largest number among the three input numbers

# %%
a,b,c = 20,30,40

if (a >= b) and (a>=c):
    print('a is greater')
elif (b >= a) and (b>=c):
    print ('b is greater')
else:
    print('c is greater')
# Out:
# c is greater

# %% [markdown]
# # Q- write a code to print all the values from 1 to 100 skip the numbers which are divisible by 3 or 5
# Q- write a code print below pattern
# ####
# ####
# ####
# ####

# %% [markdown]
# ## print the below pattern
# ![image.png](attachment:image.png)
