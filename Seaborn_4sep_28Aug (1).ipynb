# %%
#shou;d have all the libraries import

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#seaborn has some inbuilt datasets

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#load the iris dataset

data = sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Reltional plot

1. line plot

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.lineplot(data = data, x = 'sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data = data, x = 'sepal_length',y='sepal_width',hue='species',ci=None)

#ci --> confidence interval ----> estimation of population
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#Scatter plot
sns.scatterplot(data=data , x = 'sepal_length', y = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(data=data , x = 'sepal_length', y = 'petal_length',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
#relplot

#relplot by defualt is a scatter plot

#relplot can be converted into line plot by giving kind='line'

# %%
sns.relplot(data=data , x='petal_length',y = 'sepal_width',hue='species')

# %%
sns.relplot(data=data , x='petal_length',y = 'sepal_width',hue='species',kind='line',ci=None)

# %% [markdown]
# #Categorical plots
#
# ------> it is used to analyse one numerical and categorical column
#
# 1. count plot
#
# 2. box plot
#
# 3. bar plot
#
# 4. violin plot
#
# 5. strip plot
#
# 6. swarm plot
#
# 7. cat plot

# %%
#Count plot

#--> it just gives the count of categories

sns.countplot(data=data,x ='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#bar plot

#one num, one cat

sns.barplot(data=data,x='species',y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
#box plot

#box plot is used to identidy outliers

sns.boxplot(data=data,x = 'petal_length')
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.boxplot(data=data,x='species',y='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(data=data, x ='sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
#violin plot

sns.violinplot(data=data,x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
sns.violinplot(data=data,x='species',y='sepal_width')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
#strip plot

sns.stripplot(data=data,x='species',y='sepal_width',hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
#swarmplot

sns.swarmplot(data=data,x='species',y='sepal_width',hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
#cat plot

#using cat plot we can draw box,viloin,strip,swarm

sns.catplot(data=data, x='species',y='sepal_length',hue='species',kind='box')

# %%
#distribution plot

#hist
#dist

#these two graphs are used to check distribution of data

# %%
sns.distplot(x = data['sepal_length'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = data['sepal_width'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(x= data['sepal_length'],kde = True) #kde --> kernel density estimation ---> kde is approxizmation of histogram to density curve
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
#pair plot

sns.pairplot(data,hue='species')

# %%
#heat map

df1 =data.corr()
df1
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df1,annot = True)
# Out:
# <Axes: >
